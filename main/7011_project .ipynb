# %% [markdown]
# # 写在前面
#
# **查看数据文件目录  list datalab files**
#
# ```{python}
# !ls /home/tianchi/myspace
# ```
#
# **常用快捷键**
#
# 将cell变成markdown模式:m;
# 将cell变成code模式:y;

# %% [markdown]
# # 0.Load data and packages

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

engine_loacl = create_engine('mysql+pymysql://my7012:my7012@39.107.92.174/my7012', echo=False)
tagDf=pd.read_sql("select * from my7012.sentencetagdf;",engine_loacl) #tag data
oriDf=pd.read_sql("select * from my7012.sentenceclassdf;",engine_loacl) #classified (time/address) data
oriDf=pd.read_sql("select * from my7012.sentence_new limit 1500;",engine_loacl) #original data

# %% [markdown]
# # Data Analysis and Preprocessing

# %%
def removePunc(sentenceDf,key):

# %%
wordCountDict={}
for row in oriDf[].values.tolist():
    for wordItem in row:
        wordCountDict[wordItem]=wordCountDict.get(wordItem,0)+1
vocabSize=len(list(wordCountDict.keys()))

print("size of vocabulary:",vocabSize)
# Out:
# size of vocabulary:3037

# %% [markdown]
# # build multi-tast model
#
# **需要变量**:
#
# tagDf-包含SBI-SVON组合的tag
#
# **生成变量**:
#
# multiTaskModel:预测SBI和SVON的model
#
# w2vModel:word2vec的model

# %%
# data preprocessing
tagDf["text"]=tagDf["text"].apply(lambda x:x.lower())#全字母小写

# %%
# build model
from BiLSTMCRF import MyBiLSTMCRF
from CRF import CRF
myModel=MyBiLSTMCRF(vocabSize,maxLen, tagIndexDict,tagSum,sequenceLengths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-61532586cfc5> in <module>()
#       2 from BiLSTMCRF import MyBiLSTMCRF
#       3 from CRF import CRF
# ----> 4 myModel=MyBiLSTMCRF(vocabSize,maxLen, tagIndexDict,tagSum,sequenceLengths)
#
# NameError: name 'vocabSize' is not defined
